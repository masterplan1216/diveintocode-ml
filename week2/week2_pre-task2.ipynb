# %% [markdown]
# ## **ダミーデータの作成**

# %% [markdown]
# 機械学習に関するプログラムの実験を行う上で、実データではないランダムなデータ（ダミーデータ）が欲しいということがあります。正規分布に従う乱数によるダミーデータの作成を通じてNumPyの使い方になれていきましょう。
#
#
# 散布図で描くと次のようになるデータを作っていきます。

# %%
#テキストの画像を表示させようとしたが失敗。セキュリティ的に不可？

from IPython.display import Image
Image(url = "https://diveintocode.gyazo.com/29840c67d7aabcd16c3dd5325819ec65")
# Out:
# <img src="https://diveintocode.gyazo.com/29840c67d7aabcd16c3dd5325819ec65"/>

# %% [markdown]
# ![image.png](attachment:image.png)
# スクリーンショットを貼り付けてみたが、サイズの変更が不可能
# >下記参考に、![](./pic/pic1_50.png =WIDTHxHEIGHT)を試してみたが失敗
# >https://www.it-swarm-ja.tech/ja/image/markdown%E3%81%A7%E7%94%BB%E5%83%8F%E3%82%B5%E3%82%A4%E3%82%BA%E3%82%92%E5%A4%89%E6%9B%B4%E3%81%99%E3%82%8B/1071362789/

# %% [markdown]
# 【問題1】乱数の作成
# 平均が(-3, 0)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
#
# $$
# \begin{bmatrix}
# 1.0 & 0.8 \\\
# 0.8 & 1.0
# \end{bmatrix}
# $$
#
# 多次元の正規分布による乱数はnp.random.multivariate_normal()を使うことで作成できます。
# 作成したndarrayのshapeは(500, 2)になります。
#
#
# 《シード値について》
# 実行ごとに値が変わらないように、np.random.seed()により乱数のシード値を固定しておきましょう。今回シード値は0を使うことにします。

# %%
import numpy as np
np.random.seed(0) #乱数のシード値を固定

mu = [-3, 0] #平均
sigma = [[1.0, 0.8], [0.8, 1.0]] #共分散行列

#2次元正規乱数を500個作成
random_ndarray = np.random.multivariate_normal(mu, sigma, 500)
print(random_ndarray)
print(random_ndarray.shape)
# Out:
# [[-4.80006782e+00 -1.54698618e+00]
#  [-4.63714503e+00 -2.19879728e-01]
#  [-4.46267867e+00 -2.08076347e+00]
#  [-3.85346966e+00 -9.49196365e-01]
#  [-3.03192065e+00  2.27764648e-01]
#  [-3.59653339e+00  3.23229932e-01]
#  [-3.76046080e+00 -6.83506760e-01]
#  [-3.52660272e+00 -3.15568548e-01]
#  [-4.35253112e+00 -1.48228460e+00]
#  [-3.02691331e+00 -5.67090887e-01]
#  [-7.84713550e-01  2.62867115e+00]
#  [-3.58538300e+00 -1.05476937e+00]
#  [-4.69336749e+00 -2.61318911e+00]
#  [-2.98421761e+00 -1.02603072e-01]
#  [-4.91877408e+00 -9.89469999e-01]
#  [-3.26658152e+00 -2.74105461e-02]
#  [-1.53138965e+00  2.15844669e-01]
#  [-2.71938344e+00  3.79500330e-01]
#  [-4.54738211e+00 -7.86930327e-01]
#  [-2.53695299e+00  2.71853959e-01]
#  [-1.55620621e+00  5.45695585e-01]
#  [-1.99817931e+00  2.23559938e+00]
#  [-2.37797023e+00  3.44967255e-01]
#  [-2.05735800e+00  1.43437007e+00]
#  [-1.40164768e+00  1.46380355e+00]
#  [-2.27283514e+00  9.71863483e-01]
#  [-2.14205902e+00  1.11243624e-01]
# ...

# %% [markdown]
# **【問題2】散布図による可視化**
# 問題1で作成したデータ点を散布図により可視化してください。
#
#
# 散布図はmatplotlibのplt.scatter()を使うことで描けます。
# [matplotlib.pyplot.scatter — Matplotlib 3.1.1 documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib-pyplot-scatter)

# %%
from matplotlib import pyplot as plt

#散布図の作成
plt.scatter(random_ndarray[:, 0], random_ndarray[:, 1])
plt.title("random_ndarray scatter plot", fontsize=16)
plt.xlabel("x1")
plt.ylabel("x2")
plt.grid(True)
plt.show()

# %% [markdown]
# **【問題3】ヒストグラムによる可視化**
# 問題1で作成したデータをヒストグラムにより可視化してください。
#
#
# ヒストグラムはplt.hist()を使うことで描けます。
# [matplotlib.pyplot.hist — Matplotlib 3.1.1 documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html)
#
#
# 各次元ごとに作成し、2つのヒストグラムとしてください。
# それぞれのヒストグラムの横軸の範囲はplt.xlim()を用いて揃えるようにしてください。
# [matplotlib.pyplot.xlim — Matplotlib 3.1.1 documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.xlim.html)

# %%
#x1のヒストグラム
plt.hist(random_ndarray[:, 0])
plt.title("histgram of x1", fontsize=16)
plt.xlabel("random_ndarray[:, 0]")
plt.ylabel("frequency")
plt.grid(True)
plt.xlim(right=4) #横軸の範囲指定
plt.show()

#x2のヒストグラム
plt.hist(random_ndarray[:, 1])
plt.title("histgram of x2", fontsize=16)
plt.xlabel("random_ndarray[:, 1]")
plt.ylabel("frequency")
plt.grid(True)
plt.xlim(right=4)
plt.show()

# %% [markdown]
# **【問題4】データの追加**
# 新たに平均が(0, -3)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
#
# $$
# \begin{bmatrix}
# 1.0 & 0.8 \\\
# 0.8 & 1.0
# \end{bmatrix}
# $$
#
# そして、問題1、4それぞれのデータをひとつの散布図として可視化してください。凡例として問題1のものは0、問題2のものは1を表示してください。

# %%
#新たに2次元正規分布による乱数500個作成
np.random.seed(0)
mu2 = [0, -3]
sigma2 = [[1.0, 0.8], [0.8, 1.0]]
random_ndarray2 = np.random.multivariate_normal(mu2, sigma2, 500)
random_ndarray2

#散布図の表示
plt.scatter(random_ndarray[:, 0], random_ndarray[:, 1], label="0")
plt.scatter(random_ndarray2[:, 0], random_ndarray2[:, 1], label="1")
plt.title("random_ndarray&random_ndarray2 scatter plot", fontsize=16)
plt.xlabel("x1")
plt.ylabel("x2")
plt.grid(True)
plt.legend() #凡例の表示
plt.show()

# %% [markdown]
# **【問題5】データの結合**
# データはまとめておいた方が後々扱いやすいです。問題1、4で作成したndarrayを 結合 し、(1000, 2)のndarrayとしてください。結合はnp.concatenate()やnp.vstack()を使うことで行えます。
# [numpy.concatenate — NumPy v1.16 Manual](https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html)
#
#
# [numpy.vstack — NumPy v1.19 Manual](https://numpy.org/doc/stable/reference/generated/numpy.vstack.html)

# %%
#np.concatenate()を使用
linking_ndarray = np.concatenate((random_ndarray, random_ndarray2), axis=0)

#np.set_printoptions(threshold=3000) #printoptionを変更して省略をなくせる
print(linking_ndarray)
print(linking_ndarray.shape)
# Out:
# [[-4.80006782 -1.54698618]
#  [-4.63714503 -0.21987973]
#  [-4.46267867 -2.08076347]
#  ...
#  [-0.40484501 -3.14372258]
#  [ 0.1584315  -2.78199606]
#  [ 1.20196495 -2.02452628]]
# (1000, 2)

# %%
#np.vstack()を使用
linking2_ndarray = np.vstack((random_ndarray, random_ndarray2))
print(linking2_ndarray)
print(linking2_ndarray.shape)
# Out:
# [[-4.80006782 -1.54698618]
#  [-4.63714503 -0.21987973]
#  [-4.46267867 -2.08076347]
#  ...
#  [-0.40484501 -3.14372258]
#  [ 0.1584315  -2.78199606]
#  [ 1.20196495 -2.02452628]]
# (1000, 2)

# %% [markdown]
# **【問題6】ラベル付け**
# ひとまとめになった1000個のデータそれぞれに対して、問題1、4どちらで作成したものなのかを示す ラベル 付けを行ってください。問題1のものには0、問題4のものには1を対応させます。
#
#
# 0と1を含むラベルの列を新たに追加し、(1000, 3)のndarrayを作成してください。
#
#
# 機械学習に使用するデータセットはこのような形になっていることが多いです。

# %%
#np.concatenate()を使用
#次元を合わせることに留意
label_ndarray = np.hstack((np.zeros(500), np.ones(500)))
label_linking_ndarray = np.concatenate((linking_ndarray, label_ndarray.reshape(1000, 1)), axis=1)

np.set_printoptions(precision=5, suppress=True) #小数点以下5桁、指数表記無し
print(label_linking_ndarray)
# Out:
# [[-4.80007 -1.54699  0.     ]
#  [-4.63715 -0.21988  0.     ]
#  [-4.46268 -2.08076  0.     ]
#  ...
#  [-0.40485 -3.14372  1.     ]
#  [ 0.15843 -2.782    1.     ]
#  [ 1.20196 -2.02453  1.     ]]

# %%
#np.append()を使用
#次元を合わせることに留意
label_ndarray = np.hstack((np.zeros(500), np.ones(500)))
label_linking_ndarray = np.append(linking_ndarray, label_ndarray.reshape(1000, 1), axis=1)

np.set_printoptions(precision=5, suppress=True)
print(label_linking_ndarray)
# Out:
# [[-4.80007 -1.54699  0.     ]
#  [-4.63715 -0.21988  0.     ]
#  [-4.46268 -2.08076  0.     ]
#  ...
#  [-0.40485 -3.14372  1.     ]
#  [ 0.15843 -2.782    1.     ]
#  [ 1.20196 -2.02453  1.     ]]

# %%
#np.insert()を使用
#次元を合わせなくてもできた
label_ndarray = np.hstack((np.zeros(500), np.ones(500)))

label_linking_ndarray = np.insert(linking_ndarray, 2, label_ndarray, axis=1)

np.set_printoptions(precision=5, suppress=True)
print(label_linking_ndarray)
# Out:
# [[-4.80007 -1.54699  0.     ]
#  [-4.63715 -0.21988  0.     ]
#  [-4.46268 -2.08076  0.     ]
#  ...
#  [-0.40485 -3.14372  1.     ]
#  [ 0.15843 -2.782    1.     ]
#  [ 1.20196 -2.02453  1.     ]]
